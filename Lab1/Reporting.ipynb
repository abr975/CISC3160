# %% [markdown]
# <a href="https://colab.research.google.com/github/abr975/CISC3160/blob/master/Lab1/Reporting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
spotify_artist=pd.read_csv("/data.csv")

sorted_artist=spotify_artist.sort_values(by=["acousticness", "danceability"], ascending=False)

print(sorted_artist.head(50))
# Out:
#         acousticness                                    artists  danceability  \
# 112727         0.996                            ['Unspecified']         0.882
# 39703          0.996                       ['Francisco Canaro']         0.873
# 58777          0.996                       ['Francisco Canaro']         0.871
# 58712          0.996                       ['Francisco Canaro']         0.859
# 20736          0.996                       ['Francisco Canaro']         0.833
# 94134          0.996                       ['Francisco Canaro']         0.829
# 1009           0.996                       ['Francisco Canaro']         0.828
# 96316          0.996                             ['Bob Nelson']         0.828
# 145259         0.996                         ['Kaumudi Munshi']         0.827
# 782            0.996                       ['Francisco Canaro']         0.825
# 1339           0.996                       ['Francisco Canaro']         0.818
# ...
